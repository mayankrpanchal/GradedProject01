# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mayank Panchal**

# %% [markdown]
# _To grown my career, I would love to learn data science_

# %% [markdown]
# ## basic numeric view

# %%
print ("1+1")
# Out:
# 1+1

# %% [markdown]
# - Hi
#  * this is a test

# %% [markdown]
# [Homepage to learn jypter notebooks](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm)

# %% [markdown]
# ~This is a strikethrough text~
